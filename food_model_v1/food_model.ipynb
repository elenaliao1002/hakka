# %%
import glob
from IPython.display import Image, display

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15529, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 15529 (delta 49), reused 118 (delta 43), pack-reused 15393
# Receiving objects: 100% (15529/15529), 14.59 MiB | 20.69 MiB/s, done.
# Resolving deltas: 100% (10573/10573), done.
# ...

# %%
# %cd /home/ychiu14/food_model_v1/yolov5/
# !python train.py --img 416 --batch 80 --epochs 100 --data './data_food_robo.yaml' --cfg ./models/yolov5s_food_robo.yaml --weights ''
# Out:
# /home/ychiu14/food_model_v1/yolov5
# train: weights=, cfg=./models/yolov5s_food_robo.yaml, data=./data_food_robo.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=80, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /home/ychiu14/food_model_v1/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.13 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX TITAN X, 12207MiB)
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /home/ychiu14/food_model_v1/yolov5/runs
# Out:
#       <iframe id="tensorboard-frame-a6d166c07f641133" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a6d166c07f641133");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from IPython.display import Image

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/home/ychiu14/food_model_v1/yolov5/runs/train/exp2/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# use the best weights!
# Final weights will be by-default stored at /content/yolov5/runs/train/exp2/weights/best.pt
# %cd /home/ychiu14/food_model_v1/yolov5/
# !python detect.py --weights /home/ychiu14/food_model_v1/yolov5/runs/train/exp2/weights/best.pt --img 416 --conf 0.4 --source ../food_roboflow_data/test/images
# Out:
# /home/ychiu14/food_model_v1/yolov5
# detect: weights=['/home/ychiu14/food_model_v1/yolov5/runs/train/exp2/weights/best.pt'], source=../food_roboflow_data/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /home/ychiu14/food_model_v1/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.13 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX TITAN X, 12207MiB)
#
# Fusing layers...
# YOLOv5s_food_robo summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/home/ychiu14/food_model_v1/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
from utils.plots import plot_results
#plot_results('/home/ychiu14/food_model_v1/yolov5/runs/train/exp2/results.csv')
display(Image(filename='/home/ychiu14/food_model_v1/yolov5/runs/train/exp2/results.png'))

# %%
# %cd /home/ychiu14/food_model_v1/yolov5/
# !python detect.py --weights /home/ychiu14/food_model_v1/yolov5/runs/train/exp2/weights/best.pt --img 416 --conf 0.4 --source ../food_roboflow_data/test2/images
# Out:
# /home/ychiu14/food_model_v1/yolov5
# detect: weights=['/home/ychiu14/food_model_v1/yolov5/runs/train/exp2/weights/best.pt'], source=../food_roboflow_data/test2/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /home/ychiu14/food_model_v1/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.13 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce GTX TITAN X, 12207MiB)
#
# Fusing layers...
# YOLOv5s_food_robo summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/5 /home/ychiu14/food_model_v1/food_roboflow_data/test2/images/img1.jpg: 416x352 1 spaghetti, 27.3ms
# ...

# %%
for imageName in glob.glob('/home/ychiu14/food_model_v1/yolov5/runs/detect/exp4/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
def make_inference(SOURCE_PATH):
    # %cd ../yolov5/
    # !python detect.py --weights runs/train/exp2/weights/best.pt --conf 0.4 --source $SOURCE_PATH

    for imageName in glob.glob('./yolov5/runs/detect/exp7/*.jpg'): #assuming JPG
        display(Image(filename=imageName))
        print("\n")

# %%
pwd
# Out:
# '/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/yolov5'

# %%
# !rm -r ../yolov5/runs/detect/exp7

# %%
make_inference('../food_roboflow_data/test3/images')
# Out:
# /Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/yolov5
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../food_roboflow_data/test3/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.8.13 torch-1.14.0.dev20221103 CPU
#
# Fusing layers...
# YOLOv5s_food_robo summary: 157 layers, 7023610 parameters, 0 gradients
# ...

# %%
import subprocess
import os

# %%
pwd
# Out:
# '/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1'

# %%
subprocess.run(['python3', '/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/yolov5/detect.py', 
                '--source', '/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/food_roboflow_data/test3/images',
                '--weights', '/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/yolov5/runs/train/exp2/weights/best.pt',
                '--project', '/Users/annieyuchuan/Desktop/',
                '--name', 'inferenced_imgs'
                ])
# Out:
# detect: weights=['/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/yolov5/runs/train/exp2/weights/best.pt'], source=/Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/food_roboflow_data/test3/images, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/Users/annieyuchuan/Desktop/, name=inferenced_imgs, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.8.13 torch-1.14.0.dev20221103 CPU
#
# Fusing layers...
# requirements: /Users/annieyuchuan/Desktop/USF/Spring2_project/food_model_v1/requirements.txt not found, check failed.
# YOLOv5s_food_robo summary: 157 layers, 7023610 parameters, 0 gradients
# ...
